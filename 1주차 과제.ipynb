# %% [markdown]
# <a href="https://colab.research.google.com/github/huiso/AI/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("언어-- \n gnmt. \n신경망 기반 기계번역\n마이크로소프트의 인공지능 신경망 기반 번역 서비스.\n문장 전체를 번역단위로 설정하기 때문에 번역오류를 50퍼센트가량 줄일 수 있다.\n단어를 벡터목록에 인코딩 -> 각각의 벡터목록을 gnmt가 인식 후 디코더가 변환할 언어의 문장을 단어단위로 생성. 생성하는 단어와 원래 단어를 연결하는 선은 디코더 변역단어를 생성할 때 원 언어의 어떤 벡터에 가장 큰 영향을 받았는지 보여준다.\n\n")
print("음성인식--\n HMM(Hidden Markov Model)\n모델링 하는 시스템이 미지의 파라미터를 가진 Markov process일 것이라 가정\n이에 기초해 관측된 파라미터로부터 숨겨진 파라미터를 결정하려는 하나의 통계모델.\n패턴인식이나 문자인식에서도 많이 이용된다.\n\n")
print("이미지 생성--\n gan(Generative Adversarial Network)\n최대한 진짜 같은 데이터를 생성하려는 생성 모델과 진짜와 가짜를 판별하려는 분류 모델이 각각 존재하여 서로 적대적으로 학습한다.\n분류 모델을 먼저 학습시킨 후, 생성 모델을 학습시키는 과정을 서로 주고받으면서 반복한다. \n분류 모델의 학습은 진짜 데이터를 입력해서 네트워크가 해당 데이터를 진짜로 분류하도록 학습시키는 과정이 진행된다.\n생성 모델에서 생성한 가짜 데이터를 입력해서 해당 데이터를 가짜로 분류하도록 학습하는 과정으로 이뤄진다.\n이 과정을 통해 분류 모델은 진짜 데이터를 진짜로, 가짜 데이터를 가짜로 분류할 수 있게 된다.\n분류 모델을 학습시킨 다음에는 학습된 분류 모델을 속이는 방향으로 생성 모델을 학습시켜준다. \n생성 모델에서 만들어낸 가짜 데이터를 판별 모델에 입력하고, 가짜 데이터를 진짜라고 분류할 만큼 진짜 데이터와 유사한 데이터를 만들어 내도록 생성 모델을 학습시킨다.결과적으로, 생성 모델은 진짜 데이터와 완벽히 유사한 가짜 데이터를 만들 수 있게 되고 이에 따라 분류 모델은 진짜 데이터와 가짜 데이터를 구분할 수 없게 된다. \n\n")
print("자율주행--\n Faster R-CNN\nRegion Proposal Network을 핵심아이디어라 할 수 있다. \n기존 Fast RCNN 구조를 그대로 계승하면서 selective search를 제거하고 RPN을 통해서 RoI를 계산한다. \n이를 통해서 GPU를 통한 RoI 계산이 가능해졌으며, RoI 계산 역시도 학습시켜 정확도를 높일 수 있다. \n이를 통해 RPN은 Selective Search가 2000개의 RoI를 계산하는 데 반해 800개 정도의 RoI를 계산하면서도 더 높은 정확도를 보인다. \nFeature Map을 먼저 추출한 다음 이를 RPN에 전달하여 RoI를 계산한다. \n여기서 얻은 RoI로 RoI Pooling을 진행한 다음 클래시피케이션을 진행하여 Object Detection을 수행한다.")
# Out:
# 언어--
#  gnmt.
# 신경망 기반 기계번역
# 마이크로소프트의 인공지능 신경망 기반 번역 서비스.
# 문장 전체를 번역단위로 설정하기 때문에 번역오류를 50퍼센트가량 줄일 수 있다.
# 단어를 벡터목록에 인코딩 -> 각각의 벡터목록을 gnmt가 인식 후 디코더가 변환할 언어의 문장을 단어단위로 생성. 생성하는 단어와 원래 단어를 연결하는 선은 디코더 변역단어를 생성할 때 원 언어의 어떤 벡터에 가장 큰 영향을 받았는지 보여준다.
#
#
# 음성인식--
#  HMM(Hidden Markov Model)
# 모델링 하는 시스템이 미지의 파라미터를 가진 Markov process일 것이라 가정
# 이에 기초해 관측된 파라미터로부터 숨겨진 파라미터를 결정하려는 하나의 통계모델.
# 패턴인식이나 문자인식에서도 많이 이용된다.
#
#
# 이미지 생성--
#  gan(Generative Adversarial Network)
# 최대한 진짜 같은 데이터를 생성하려는 생성 모델과 진짜와 가짜를 판별하려는 분류 모델이 각각 존재하여 서로 적대적으로 학습한다.
# 분류 모델을 먼저 학습시킨 후, 생성 모델을 학습시키는 과정을 서로 주고받으면서 반복한다.
# 분류 모델의 학습은 진짜 데이터를 입력해서 네트워크가 해당 데이터를 진짜로 분류하도록 학습시키는 과정이 진행된다.
# 생성 모델에서 생성한 가짜 데이터를 입력해서 해당 데이터를 가짜로 분류하도록 학습하는 과정으로 이뤄진다.
# 이 과정을 통해 분류 모델은 진짜 데이터를 진짜로, 가짜 데이터를 가짜로 분류할 수 있게 된다.
# 분류 모델을 학습시킨 다음에는 학습된 분류 모델을 속이는 방향으로 생성 모델을 학습시켜준다.
# ...

# %% [markdown]
# ##언어--
# ####gnmt.
# 신경망 기반 기계번역
#
# 마이크로소프트의 인공지능 신경망 기반 번역 서비스.
#
# 문장 전체를 번역단위로 설정하기 때문에 번역오류를 50퍼센트가량 줄일 수 있다.
#
# 단어를 벡터목록에 인코딩 -> 각각의 벡터목록을 gnmt가 인식 후 디코더가 변환할 언어의 문장을 단어단위로 생성.
#
# 생성하는 단어와 원래 단어를 연결하는 선은 디코더 변역단어를 생성할 때 원 언어의 어떤 벡터에 가장 큰 영향을 받았는지 보여준다.
#
# ##음성인식--
# ####HMM(Hidden Markov Model)
# 모델링 하는 시스템이 미지의 파라미터를 가진 Markov process일 것이라 가정
#
# 이에 기초해 관측된 파라미터로부터 숨겨진 파라미터를 결정하려는 하나의 통계모델.
#
# 패턴인식이나 문자인식에서도 많이 이용된다.
#
# ##이미지 생성--
# ####gan(Generative Adversarial Network)
# 최대한 진짜 같은 데이터를 생성하려는 생성 모델과 진짜와 가짜를 판별하려는 분류 모델이 각각 존재하여 서로 적대적으로 학습한다.
#
# 분류 모델을 먼저 학습시킨 후, 생성 모델을 학습시키는 과정을 서로 주고받으면서 반복한다.
#
# 분류 모델의 학습은 진짜 데이터를 입력해서 네트워크가 해당 데이터를 진짜로 분류하도록 학습시키는 과정이 진행된다.
#
# 생성 모델에서 생성한 가짜 데이터를 입력해서 해당 데이터를 가짜로 분류하도록 학습하는 과정으로 이뤄진다.
#
# 이 과정을 통해 분류 모델은 진짜 데이터를 진짜로, 가짜 데이터를 가짜로 분류할 수 있게 된다.
#
# 분류 모델을 학습시킨 다음에는 학습된 분류 모델을 속이는 방향으로 생성 모델을 학습시켜준다.
#
# 생성 모델에서 만들어낸 가짜 데이터를 판별 모델에 입력하고, 가짜 데이터를 진짜라고 분류할 만큼 진짜 데이터와 유사한 데이터를 만들어 내도록 생성 모델을 학습시킨다.
#
# 결과적으로, 생성 모델은 진짜 데이터와 완벽히 유사한 가짜 데이터를 만들 수 있게 되고 이에 따라 분류 모델은 진짜 데이터와 가짜 데이터를 구분할 수 없게 된다.
#
# ##자율주행--
# ####Faster R-CNN
# Region Proposal Network을 핵심아이디어라 할 수 있다.
#
# 기존 Fast RCNN 구조를 그대로 계승하면서 selective search를 제거하고 RPN을 통해서 RoI를 계산한다.
#
# 이를 통해서 GPU를 통한 RoI 계산이 가능해졌으며, RoI 계산 역시도 학습시켜 정확도를 높일 수 있다.
#
# 이를 통해 RPN은 Selective Search가 2000개의 RoI를 계산하는 데 반해 800개 정도의 RoI를 계산하면서도 더 높은 정확도를 보인다.
#
# Feature Map을 먼저 추출한 다음 이를 RPN에 전달하여 RoI를 계산한다.
#
# 여기서 얻은 RoI로 RoI Pooling을 진행한 다음 클래시피케이션을 진행하여 Object Detection을 수행한다.
